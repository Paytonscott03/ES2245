# %% [markdown]
# <a href="https://colab.research.google.com/github/crowell97/ES2245/blob/main/test_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy

# %% [markdown]
# This is just a test notebook

# %%
a = numpy.random.randn(500,1)

# %%
import matplotlib.pylab as plt
plt.plot(a)

# %%
print(numpy.std(a))
# Out:
# 0.959925265067122
